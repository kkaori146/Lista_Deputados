# %% [markdown]
# ###Instalação do Pyarrow

# %%
pip install pyarrow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ###Importação das bibliotecas

# %%
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq

# %% [markdown]
# ###Lista de Políticos

# %%
# Carregamento do Dataframe Localmente em csv

dfppandas = pd.read_csv('/content/lista_final.csv',sep=',')

# %%
# Visão geral da tabela em csv

dfppandas
# Out:
#         Ano  Matricula  Mes    Valor            CNPJ           Deputado  \
# 0      2019     300605    3  7200.00   8390859000166  ADALBERTO FREITAS
# 1      2019     300605    3    30.00  17781480000178  ADALBERTO FREITAS
# 2      2019     300605    3     4.00  28720558000160  ADALBERTO FREITAS
# 3      2019     300605    3  2296.85  43283811003841  ADALBERTO FREITAS
# 4      2019     300605    3   168.75  43283811006867  ADALBERTO FREITAS
# ...     ...        ...  ...      ...             ...                ...
# 26722  2022     300540    4   100.00  55846752000160        CAIO FRANÇA
# 26723  2022     300540    4   335.36  61786729000120        CAIO FRANÇA
# 26724  2022     300540    4   290.09  72722309000104        CAIO FRANÇA
# 26725  2022     300540    4   120.80   4088208000165        CAIO FRANÇA
# 26726  2022     300540    4   279.80  16577631000299        CAIO FRANÇA
#
#                                                     Tipo  \
# ...

# %%
# Conversão de csv para parquet

dfppandas.to_parquet('lista_politicos.parquet')

# %%
# Carregamento do Dataframe Localmente em parquet

df = pd.read_parquet('/content/lista_politicos.parquet')

# %%
# Visão geral da tabela

df
# Out:
#         Ano  Matricula  Mes    Valor            CNPJ           Deputado  \
# 0      2019     300605    3  7200.00   8390859000166  ADALBERTO FREITAS
# 1      2019     300605    3    30.00  17781480000178  ADALBERTO FREITAS
# 2      2019     300605    3     4.00  28720558000160  ADALBERTO FREITAS
# 3      2019     300605    3  2296.85  43283811003841  ADALBERTO FREITAS
# 4      2019     300605    3   168.75  43283811006867  ADALBERTO FREITAS
# ...     ...        ...  ...      ...             ...                ...
# 26722  2022     300540    4   100.00  55846752000160        CAIO FRANÇA
# 26723  2022     300540    4   335.36  61786729000120        CAIO FRANÇA
# 26724  2022     300540    4   290.09  72722309000104        CAIO FRANÇA
# 26725  2022     300540    4   120.80   4088208000165        CAIO FRANÇA
# 26726  2022     300540    4   279.80  16577631000299        CAIO FRANÇA
#
#                                                     Tipo  \
# ...
